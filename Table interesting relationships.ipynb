# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

print(__version__) # requires version >= 1.9.0
# Out:
# 4.5.4

# %%
import cufflinks as cf
init_notebook_mode(connected=True)
# For offline use
cf.go_offline()
from pandas_datareader import data, wb

import datetime
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
# ...

# %%
# show all columns 

pd.set_option('display.max_columns', None)

# %%
df=pd.read_csv('//home/jorgemsr123/Desktop/Pavita/CSV_tables/tabla_todas_correlacion_completa',header=[0])

# %%
df
# Out:
#                           Unnamed: 0  suma_dientes_x  numero_de_caries  \
# 0                     suma_dientes_x        1.000000          0.548392
# 1                   numero_de_caries        0.548392          1.000000
# 2    numero_de_dientes_caries_no_obs        0.079790         -0.042189
# 3      porcentaje_dientes_con_caries       -0.317184          0.471644
# 4                            car_P_1        0.549486          0.813223
# ..                               ...             ...               ...
# 107                           Sexo_M        0.006508         -0.017208
# 108                 Rango Edad_16-20        0.139027          0.223059
# 109                 Rango Edad_20-35       -0.006581          0.110599
# 110                 Rango Edad_35-50        0.057209         -0.257628
# 111                   Rango Edad_>50       -0.249419         -0.110927
#
#      numero_de_dientes_caries_no_obs  porcentaje_dientes_con_caries   car_P_1  \
# ...

# %%
df.sort_values(by='mol_F_0', ascending=False).head(10)
# Out:
#                Unnamed: 0  suma_dientes_x  numero_de_caries  \
# 68                mol_F_0        0.274220          0.085601
# 58                mol_D_0        0.274220          0.085601
# 49                mol_G_1        0.277427          0.118171
# 108      Rango Edad_16-20        0.139027          0.223059
# 38                 ds_G_0        0.363399          0.166710
# 69                mol_F_1        0.440243          0.369741
# 59                mol_D_1        0.451164          0.375507
# 37           #_bajo_scott        0.425864          0.423979
# 50                mol_G_2        0.503994          0.474747
# 79   Sitio_02 Palma Torre       -0.112075         -0.082786
#
#      numero_de_dientes_caries_no_obs  porcentaje_dientes_con_caries   car_P_1  \
# 68                          0.080753                      -0.144198  0.136410
# 58                          0.080753                      -0.144198  0.136410
# ...

# %%
df_desg=pd.read_csv('//home/jorgemsr123/Desktop/Pavita/tabla_todas_desgaste',header=[0])

# %%
df['Sitio_02 Palma Torre']
# Out:
# 0     -0.112075
# 1     -0.082786
# 2     -0.080153
# 3     -0.033673
# 4     -0.029275
#          ...
# 107   -0.094955
# 108    0.275692
# 109   -0.128037
# 110   -0.069148
# 111   -0.041910
# Name: Sitio_02 Palma Torre, Length: 112, dtype: float64
